# %% [markdown]
# # Práctica: Despliegue y uso de modelos en AI Foundry
#
# Este repositorio contiene la práctica para aprender a desplegar y usar modelos en AI Foundry. La práctica está dividida en 3 partes independientes. Cada parte debe entregarse como un notebook Jupyter (`.ipynb`) con un nombre claro y apropiado.

# %% [markdown]
# ## Configuración / Credenciales
#
# Antes de comenzar, configure las siguientes variables de entorno en su máquina local:
#
# ```bash
# # En Windows
# set AZURE_FOUNDRY_ENDPOINT=<tu_endpoint>
# set AZURE_FOUNDRY_API_KEY=<tu_api_key>
#
# # En Linux/Mac
# export AZURE_FOUNDRY_ENDPOINT=<tu_endpoint>
# export AZURE_FOUNDRY_API_KEY=<tu_api_key>
# ```

# %% [markdown]
# ---
#
# # 1) Text, JSON y Guardrails
#
# **Objetivo:** Desplegar un modelo y realizar tres tipos de interacciones

# %% [markdown]
# ## 1.1 - Generar texto
#
# Simple generación de texto con system prompt y user prompt.
#
# ⭐ **Suma puntos:** Crear un chat interactivo por CLI que persista la memoria a corto plazo.
#
# [Documentación - Generar respuestas](https://learn.microsoft.com/en-us/azure/foundry/foundry-models/how-to/generate-responses?tabs=python)

# %% [markdown]
# ## 1.2 - Generar respuesta estructurada en JSON
#
# Generación de respuesta estructurada en formato JSON.
#
# [Documentación - Structured Outputs](https://learn.microsoft.com/en-us/azure/foundry/openai/how-to/structured-outputs?tabs=python-secure%2Cdotnet-entra-id&pivots=programming-language-python)

# %% [markdown]
# ## 1.3 - Implementar y demostrar Guardrails
#
# Crear Guardrails para el modelo, documentar el proceso y hacer pruebas contra el modelo.
#
# [Documentación - Guardrails](https://learn.microsoft.com/en-us/azure/foundry/guardrails/how-to-create-guardrails?tabs=python)

# %% [markdown]
# ### Conclusiones - Parte 1
#
# Resuma los hallazgos y problemas encontrados durante esta sección.

# %% [markdown]
# ---
#
# # 2) Reasoning y Function Calling
#
# **Objetivo:** Practicar con modelos razonadores y ver el function calling

# %% [markdown]
# ## 2.1 - Razonamiento
#
# Desplegar un modelo razonador y parametrizar distintos grados de razonamiento (low, medium, high).
#
# [Documentación - Reasoning](https://learn.microsoft.com/en-us/azure/foundry/openai/how-to/reasoning?tabs=csharp%2Cgpt-5)

# %% [markdown]
# ## 2.2 - Function Calling
#
# Activar un motor de búsqueda web para probar llamadas a funciones (`function calling`) que recuperen información externa.
#
# ⭐ **Suma puntos:** Usar deep research o hacer function calling con una función custom.
#
# [Documentación - Web Search](https://learn.microsoft.com/en-us/azure/foundry/openai/how-to/web-search)

# %% [markdown]
# ### Conclusiones - Parte 2
#
# Resuma los hallazgos sobre razonamiento y function calling.

# %% [markdown]
# ---
#
# # 3) Modelos Multimodales
#
# **Objetivo:** Desplegar un modelo multimodal y probar interacciones que involucren imágenes, audio y/o texto combinado.
#
# [Documentación - Modelos Multimodales](https://learn.microsoft.com/en-us/azure/foundry-classic/foundry-models/how-to/use-chat-multi-modal?context=%2Fazure%2Ffoundry%2Fcontext%2Fcontext&pivots=programming-language-python)

# %% [markdown]
# ## 3.1 - Procesamiento de Imágenes
#
# Subida y consulta de imágenes usando el modelo multimodal.

# %% [markdown]
# ## 3.2 - Procesamiento de Audio
#
# Transcripción y procesamiento de audio con modelos multimodales.

# %% [markdown]
# ## 3.3 - Prompts Mixtos (Texto + Media)
#
# Combinación de texto, imágenes y audio en una misma solicitud.

# %% [markdown]
# ### Conclusiones - Parte 3
#
# Resuma los hallazgos sobre modelos multimodales y formatos soportados.

# %% [markdown]
# ---
#
# ## Criterios de Entrega
#
# Cada parte debe incluir:
#
# ✓ **Configuración / Credenciales:** Explicando cómo configurar variables de entorno localmente.
#
# ✓ **Código reproducible:** Conecta a un modelo ya desplegado, realiza las llamadas y procesa las respuestas.
#
# ✓ **Celdas de explicación y resultados visibles:** Salidas, figuras, JSON validados.
#
# ✓ **Conclusiones y problemas encontrados:** Resumen final de cada sección.
